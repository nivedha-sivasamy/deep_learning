# %% [markdown]
# # Object Detection
#
# ## Aim: Implement object detection using opencv for general objects and face of persons.
# ## Dataset: Images of objects and person

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install cvlib -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 75.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
# ...

# %%
import cv2
import cvlib as cv
from google.colab.patches import cv2_imshow
from cvlib.object_detection import draw_bbox
import numpy as np

# %%
# Object Detection
image = cv2.imread("/content/drive/MyDrive/1.jpg")

bbox, label, conf = cv.detect_common_objects(image)

output_image = draw_bbox(image, bbox, label, conf)
cv2_imshow(output_image)
# Out:
#   0% |                                                                        |
# ...
# <PIL.Image.Image image mode=RGB size=595x396 at 0x7F74CC242C10>

# %%
path='/content/drive/MyDrive/2.png'

# %%
# Face detection
image = cv2.imread(path)

# apply face detection
faces, confidences = cv.detect_face(image)

print("faces: ",faces)
print("Confidences: ",confidences)

# loop through detected faces
for face,conf in zip(faces,confidences):

    (startX,startY) = face[0],face[1]
    (endX,endY) = face[2],face[3]

    # draw rectangle over face
    cv2.rectangle(image, (startX,startY), (endX,endY), (0,255,0), 2)

cv2_imshow(image)
# Out:
# faces:  [[453, 38, 503, 105], [106, 69, 165, 150], [228, 56, 285, 132], [549, 73, 604, 144], [374, 59, 425, 139], [313, 137, 373, 222], [633, 176, 701, 242], [176, 216, 230, 286], [400, 239, 458, 325], [74, 211, 131, 288]]
# Confidences:  [0.99766845, 0.99716395, 0.99654263, 0.9954919, 0.99454653, 0.9894447, 0.983604, 0.9732756, 0.9725645, 0.9572043]
# <PIL.Image.Image image mode=RGB size=764x498 at 0x7F741602E4F0>

# %% [markdown]
# ## Conclusion: The program for object detection for face could not detect one of the persons face.
